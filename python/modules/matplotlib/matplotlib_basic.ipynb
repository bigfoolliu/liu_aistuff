# %% [markdown]
# # matplotlib
# 1. 主要用于2D图表

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.arange(100))

# %% [markdown]
# #### 创建一个图像

# %%
fig1 = plt.figure()

# 增加几个子图
ax1 = fig1.add_subplot(2, 2, 1)
ax2 = fig1.add_subplot(2, 2, 2)
ax3 = fig1.add_subplot(2, 2, 3)
ax4 = fig1.add_subplot(2, 2, 4)

plt.plot([1, 2, 3, 5, 2, 7, 5])

# %%
plt.plot([3, 2, 4, 5, 2, 5, 6])

# %% [markdown]
# #### 画一条正弦曲线
# y = sin(x), -2pi<=x<=2pi

# %%
import matplotlib.pyplot as plt
import numpy as mp
from numpy import *

x = np.arange(-2*pi, 2*pi, 0.02)  # x的区间以及间隔点
y = np.sin(x)
plot1 = plt.plot(x, y)

plt.legend("正弦曲线")  # 增加图例
plt.grid()  # 增加网格

# %%
print(type(plot1))
# Out:
# <class 'list'>

# %% [markdown]
# #### 简单实例

# %%
plt.plot(np.arange(0, 10))  # 画一条直线

# 增加x,y轴说明
plt.xlabel("x")
plt.ylabel("y")

plt.grid()

plt.show()  # 其他环境编程需要添加此句

# %% [markdown]
# #### pyplot(x, y, format_str)
# 后面指定参数:
#
# - 字符	  颜色
# - ‘b’	  蓝色，blue
# - ‘g’	  绿色，green
# - ‘r’	  红色，red
# - ‘c’	  青色，cyan
# - ‘m’	  品红，magenta
# - ‘y’	  黄色，yellow
# - ‘k’	  黑色，black
# - ‘w’	  白色，white
#
#
# - 字符     线型
# - '-'      实线
# - '--'     虚线
# - '.'      点
# - 's'      正方形
# - ','      像素点
# - '*'      星形点
# - ':'      点线

# %%
# 红色圆点
plt.plot([1, 2, 3, 4], [2, 3, 6, 3], 'r.')

# %%
# 绿色虚线
plt.plot(x, y,'g--')

# %% [markdown]
# #### 指定轴的显示范围
# plt.axis([xmin, xmax, ymin, ymax])

# %%
plt.plot(x, y, 'ks')
plt.axis([-5, 5, -1, 1])
# Out:
# [-5, 5, -1, 1]

# %% [markdown]
# #### 可以同时传入多条线

# %%
y0 = x
y1 = x ** 2
y2 = x ** 3

plt.plot(x, y0, 'k',
         x, y1, 'r',
         x, y2, 'b')

# %% [markdown]
# #### 直方图
# plt.hist()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='g', alpha=0.75)
print(type(n))
print(type(bins))
print(type(patches))

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')  # 增加图像标题

plt.text(60, .025, r'$\mu=100,\sigma=15$')  # 增加文本
plt.axis([40, 160, 0, 0.03])

plt.grid(True)
plt.show()
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'matplotlib.cbook.silent_list'>

# %% [markdown]
# #### 设置文本以及箭头
# annoate()函数进行注释,主要参数:
# 1. xy: 注释位置
# 2. xytext: 注释文字位置

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

plt.ylim(-2,2)
plt.show()

# %% [markdown]
# ### 使用style配置pyplot风格

# %%
# 查看有哪些可用的风格
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  '_classic_test']

# %%
x = np.linspace(0, 2 * np.pi)
y = np.sin(x)

plt.style.use('bmh')

plt.plot(x, y)

plt.show()

# %% [markdown]
# ### 文本添加

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# plt.figure() 返回一个 Figure() 对象
fig = plt.figure(figsize=(12, 9))

# 设置这个 Figure 对象的标题
# 事实上，如果我们直接调用 plt.suptitle() 函数，它会自动找到当前的 Figure 对象
fig.suptitle('bold figure suptitle', fontsize=14, fontweight='bold')

# Axes 对象表示 Figure 对象中的子图
# 这里只有一幅图像，所以使用 add_subplot(111)
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)

# 可以直接使用 set_xxx 的方法来设置标题
ax.set_title('axes title')
# 也可以直接调用 title()，因为会自动定位到当前的 Axes 对象
# plt.title('axes title')

ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')

# 添加文本，斜体加文本框
ax.text(3, 8, 'boxed italics text in data coords', style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})

# 数学公式，用 $$ 输入 Tex 公式
ax.text(2, 6, r'an equation: $E=mc^2$', fontsize=15)


# 颜色，对齐方式
ax.text(0.95, 0.01, 'colored text in axes coords',
        verticalalignment='bottom', horizontalalignment='right',
        transform=ax.transAxes,
        color='green', fontsize=15)

# 注释文本和箭头
ax.plot([2], [1], 'o')
ax.annotate('annotate', xy=(2, 1), xytext=(3, 4),
            arrowprops=dict(facecolor='black', shrink=0.05))

# 设置显示范围
ax.axis([0, 10, 0, 10])

plt.show()

# %% [markdown]
# #### 极坐标系注释文本
# 要在subplot()参数中设置polar=True

# %%
fig = plt.figure()
ax = fig.add_subplot(111, polar=True)
r = np.arange(0,1,0.001)
theta = 2*2*np.pi*r
line, = ax.plot(theta, r, color='#ee8d18', lw=3)

ind = 800
thisr, thistheta = r[ind], theta[ind]
ax.plot([thistheta], [thisr], 'o')
ax.annotate('a polar annotation',
            xy=(thistheta, thisr),  # theta, radius
            xytext=(0.05, 0.05),    # fraction, fraction
            textcoords='figure fraction',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='left',
            verticalalignment='bottom',
            )
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 2 * np.pi)
y = np.sin(x)

plt.style.use('bmh')

plt.plot(x, y)

plt.show()

# %%
1 + 2
# Out:
# 3

# %%
1
